# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib


#그래프 한글 인코딩 설정
matplotlib.rcParams['font.family'] ='Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] =False


employ_2019 = pd.read_csv('All_2018,2019.csv',encoding='euc-kr')


employ_region = employ_2019['시도별']

employ_2019_1_now = employ_2019['2019.1/2']
employ_2019_1_required = employ_2019['2019.1/2.1']
employ_2019_1_lack = employ_2019['2019.1/2.4']
employ_2019_1_lack_rate = employ_2019['2019.1/2.6']

employ_2019_2_now = employ_2019['2019.2/2']
employ_2019_2_required = employ_2019['2019.2/2.1']
employ_2019_2_lack = employ_2019['2019.2/2.4']
employ_2019_2_lack_rate = employ_2019['2019.2/2.6']

employ_2020 = pd.read_csv('All_2020.csv',encoding='euc-kr')

employ_2020_1_now = employ_2020['2020.1/2']
employ_2020_1_required = employ_2020['2020.1/2.1']
employ_2020_1_lack = employ_2020['2020.1/2.4']
employ_2020_1_lack_rate = employ_2020['2020.1/2.6']

employ_2020_2_now = employ_2020['2020.2/2']
employ_2020_2_required = employ_2020['2020.2/2.1']
employ_2020_2_lack = employ_2020['2020.2/2.4']
employ_2020_2_lack_rate = employ_2020['2020.2/2.6']

employ_2021a = pd.read_csv('All_2021.csv',encoding='euc-kr')

employ_2021_1_now = employ_2021a['2021.1/2']
employ_2021_1_required = employ_2021a['2021.1/2.1']
employ_2021_1_lack = employ_2021a['2021.1/2.4']
employ_2021_1_lack_rate = employ_2021a['2021.1/2.6']

employ_2021_2_now = employ_2021a['2021.2/2']
employ_2021_2_required = employ_2021a['2021.2/2.1']
employ_2021_2_lack = employ_2021a['2021.2/2.4']
employ_2021_2_lack_rate = employ_2021a['2021.2/2.6']

employ_2022_1_now = employ_2021a['2022.1/2']
employ_2022_1_required = employ_2021a['2022.1/2.1']
employ_2022_1_lack = employ_2021a['2022.1/2.4']
employ_2022_1_lack_rate = employ_2021a['2022.1/2.6']

employ_2022_2_now = employ_2021a['2022.2/2']
employ_2022_2_required = employ_2021a['2022.2/2.1']
employ_2022_2_lack = employ_2021a['2022.2/2.4']
employ_2022_2_lack_rate = employ_2021a['2022.2/2.6']

# %%
x =employ_region[2:18]
y=[]
for row in employ_2019_1_lack_rate.iloc[2:18]:
    y.append((float)(row))
plt.figure(1)
plt.title('부족율')
plt.plot(x,y)
plt.legend()
plt.xticks(rotation=90)

x_total = ['2019_1','2019_2','2020_1','2020_2','2021_1','2021_2','2022_1','2022_2']
total = []
total.append((float)(employ_2019_1_now[1]))
total.append((float)(employ_2019_2_now[1]))
total.append((float)(employ_2020_1_now[1]))
total.append((float)(employ_2020_2_now[1]))
total.append((float)(employ_2021_1_now[1]))
total.append((float)(employ_2021_2_now[1]))
total.append((float)(employ_2022_1_now[1]))
total.append((float)(employ_2022_2_now[1]))

plt.figure(2)
plt.title('전국 경제인구')
plt.plot(x_total,total)
plt.legend()
plt.xticks(rotation=90)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ([0, 1, 2, 3, 4, 5, 6, 7],
#  [Text(0, 0, '2019_1'),
#   Text(1, 0, '2019_2'),
#   Text(2, 0, '2020_1'),
#   Text(3, 0, '2020_2'),
#   Text(4, 0, '2021_1'),
#   Text(5, 0, '2021_2'),
#   Text(6, 0, '2022_1'),
#   Text(7, 0, '2022_2')])

# %%
foreign_worker_original = pd.read_csv('foreign1.csv',encoding='euc-kr')
foreign_insurance_1 = pd.read_csv('foreign_insurance.csv',encoding='euc-kr')


foreign_worker = foreign_worker_original.iloc[1:2]


x=[]
x.append((float)(foreign_worker['2012.2']))
x.append((float)(foreign_worker['2013.2']))
x.append((float)(foreign_worker['2014.2']))
x.append((float)(foreign_worker['2015.2']))
x.append((float)(foreign_worker['2016.2']))
x.append((float)(foreign_worker['2017.2']))
x.append((float)(foreign_worker['2018.2']))
x.append((float)(foreign_worker['2019.2']))
x.append((float)(foreign_worker['2020.2']))
x.append((float)(foreign_worker['2021.2']))
#x.append((float)(foreign_worker['2022.2']))

x2 =[]
x2.append((float)(foreign_worker['2012.3']))
x2.append((float)(foreign_worker['2013.3']))
x2.append((float)(foreign_worker['2014.3']))
x2.append((float)(foreign_worker['2015.3']))
x2.append((float)(foreign_worker['2016.3']))
x2.append((float)(foreign_worker['2017.3']))
x2.append((float)(foreign_worker['2018.3']))
x2.append((float)(foreign_worker['2019.3']))
x2.append((float)(foreign_worker['2020.3']))
x2.append((float)(foreign_worker['2021.3']))

foreign_insurance = foreign_insurance_1[1:2]

y=[]

y.append((int)(foreign_insurance['2012.1']))
y.append((int)(foreign_insurance['2013.1']))
y.append((int)(foreign_insurance['2014.1']))
y.append((float)(foreign_insurance['2015.1']))
y.append((float)(foreign_insurance['2016.1']))
y.append((float)(foreign_insurance['2017.1']))
y.append((float)(foreign_insurance['2018.1']))
y.append((float)(foreign_insurance['2019.1']))
y.append((float)(foreign_insurance['2020.1']))
y.append((float)(foreign_insurance['2021.1']))
#y.append((float)(foreign_insurance['2022.1']))
plt.figure(1)
plt.plot(x,y,'o')
plt.figure(2)
plt.plot(x2,y,'o')
# Out:
# C:\Users\voice\AppData\Local\Temp\ipykernel_23836\2287069326.py:9: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   x.append((float)(foreign_worker['2012.2']))
# C:\Users\voice\AppData\Local\Temp\ipykernel_23836\2287069326.py:10: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   x.append((float)(foreign_worker['2013.2']))
# C:\Users\voice\AppData\Local\Temp\ipykernel_23836\2287069326.py:11: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   x.append((float)(foreign_worker['2014.2']))
# C:\Users\voice\AppData\Local\Temp\ipykernel_23836\2287069326.py:12: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
# ...

# %%
import statsmodels.api as sm
x = sm.add_constant(x)

model_1 = sm.OLS(y,x).fit()

model_2 = sm.OLS(y,x2).fit()

print(model_1.summary())

#print(model_2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.507
# Model:                            OLS   Adj. R-squared:                  0.445
# Method:                 Least Squares   F-statistic:                     8.213
# Date:                Mon, 10 Jul 2023   Prob (F-statistic):             0.0210
# Time:                        18:22:25   Log-Likelihood:                -256.41
# No. Observations:                  10   AIC:                             516.8
# Df Residuals:                       8   BIC:                             517.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -2.004e+11   1.33e+11     -1.511      0.169   -5.06e+11    1.05e+11
# ...

# %%
foreign_worker = pd.read_csv('e9.csv',encoding='euc-kr')
foreign_insurance_1 = pd.read_csv('insurance2.csv',encoding='euc-kr')


foreign_worker = foreign_worker.iloc[0:1]

foreign_insurance = foreign_insurance_1.iloc[1:2]

foreign_insurance_B = foreign_insurance_1.iloc[2:3]

foreign_insurance_c = foreign_insurance_1.iloc[3:4]

foreign_insurance_I = foreign_insurance_1.iloc[6:7]

foreign_insurance_P = foreign_insurance_1.iloc[17:18]

foreign_insurance_M = foreign_insurance_1.iloc[10:11]

foreign_insurance_PA = foreign_insurance_1.iloc[15:16]

foreign_insurance_Vie = foreign_insurance_1.iloc[23:24]

foreign_insurance_Uz = foreign_insurance_1.iloc[22:23]

y = []

y.append((int)(foreign_insurance['2004']))
y.append((int)(foreign_insurance['2005']))
y.append((int)(foreign_insurance['2006']))
y.append((int)(foreign_insurance['2007']))
y.append((int)(foreign_insurance['2008']))
y.append((int)(foreign_insurance['2009']))
y.append((int)(foreign_insurance['2010']))
y.append((int)(foreign_insurance['2011']))
y.append((int)(foreign_insurance['2012']))
y.append((int)(foreign_insurance['2013']))
y.append((int)(foreign_insurance['2014']))
y.append((int)(foreign_insurance['2015']))
y.append((int)(foreign_insurance['2016']))
y.append((int)(foreign_insurance['2017']))
y.append((int)(foreign_insurance['2018']))
y.append((int)(foreign_insurance['2019']))
y.append((int)(foreign_insurance['2020']))
y.append((int)(foreign_insurance['2021']))




y1 = []

y1.append((int)(foreign_insurance['2004.1']))
y1.append((int)(foreign_insurance['2005.1']))
y1.append((int)(foreign_insurance['2006.1']))
y1.append((int)(foreign_insurance['2007.1']))
y1.append((int)(foreign_insurance['2008.1']))
y1.append((int)(foreign_insurance['2009.1']))
y1.append((int)(foreign_insurance['2010.1']))
y1.append((int)(foreign_insurance['2011.1']))
y1.append((int)(foreign_insurance['2012.1']))
y1.append((int)(foreign_insurance['2013.1']))
y1.append((int)(foreign_insurance['2014.1']))
y1.append((int)(foreign_insurance['2015.1']))
y1.append((int)(foreign_insurance['2016.1']))
y1.append((int)(foreign_insurance['2017.1']))
y1.append((int)(foreign_insurance['2018.1']))
y1.append((int)(foreign_insurance['2019.1']))
y1.append((int)(foreign_insurance['2020.1']))
y1.append((int)(foreign_insurance['2021.1']))

y_c = []

y_c.append((int)(foreign_insurance_c['2004.1']))
y_c.append((int)(foreign_insurance_c['2005.1']))
y_c.append((int)(foreign_insurance_c['2006.1']))
y_c.append((int)(foreign_insurance_c['2007.1']))
y_c.append((int)(foreign_insurance_c['2008.1']))
y_c.append((int)(foreign_insurance_c['2009.1']))
y_c.append((int)(foreign_insurance_c['2010.1']))
y_c.append((int)(foreign_insurance_c['2011.1']))
y_c.append((int)(foreign_insurance_c['2012.1']))
y_c.append((int)(foreign_insurance_c['2013.1']))
y_c.append((int)(foreign_insurance_c['2014.1']))
y_c.append((int)(foreign_insurance_c['2015.1']))
y_c.append((int)(foreign_insurance_c['2016.1']))
y_c.append((int)(foreign_insurance_c['2017.1']))
y_c.append((int)(foreign_insurance_c['2018.1']))
y_c.append((int)(foreign_insurance_c['2019.1']))
y_c.append((int)(foreign_insurance_c['2020.1']))
y_c.append((int)(foreign_insurance_c['2021.1']))

y_I =[]

y_I.append((int)(foreign_insurance_I['2004.1']))
y_I.append((int)(foreign_insurance_I['2005.1']))
y_I.append((int)(foreign_insurance_I['2006.1']))
y_I.append((int)(foreign_insurance_I['2007.1']))
y_I.append((int)(foreign_insurance_I['2008.1']))
y_I.append((int)(foreign_insurance_I['2009.1']))
y_I.append((int)(foreign_insurance_I['2010.1']))
y_I.append((int)(foreign_insurance_I['2011.1']))
y_I.append((int)(foreign_insurance_I['2012.1']))
y_I.append((int)(foreign_insurance_I['2013.1']))
y_I.append((int)(foreign_insurance_I['2014.1']))
y_I.append((int)(foreign_insurance_I['2015.1']))
y_I.append((int)(foreign_insurance_I['2016.1']))
y_I.append((int)(foreign_insurance_I['2017.1']))
y_I.append((int)(foreign_insurance_I['2018.1']))
y_I.append((int)(foreign_insurance_I['2019.1']))
y_I.append((int)(foreign_insurance_I['2020.1']))
y_I.append((int)(foreign_insurance_I['2021.1']))

y_B = []

y_B.append((int)(foreign_insurance_B['2004.1']))
y_B.append((int)(foreign_insurance_B['2005.1']))
y_B.append((int)(foreign_insurance_B['2006.1']))
y_B.append((int)(foreign_insurance_B['2007.1']))
y_B.append((int)(foreign_insurance_B['2008.1']))
y_B.append((int)(foreign_insurance_B['2009.1']))
y_B.append((int)(foreign_insurance_B['2010.1']))
y_B.append((int)(foreign_insurance_B['2011.1']))
y_B.append((int)(foreign_insurance_B['2012.1']))
y_B.append((int)(foreign_insurance_B['2013.1']))
y_B.append((int)(foreign_insurance_B['2014.1']))
y_B.append((int)(foreign_insurance_B['2015.1']))
y_B.append((int)(foreign_insurance_B['2016.1']))
y_B.append((int)(foreign_insurance_B['2017.1']))
y_B.append((int)(foreign_insurance_B['2018.1']))
y_B.append((int)(foreign_insurance_B['2019.1']))
y_B.append((int)(foreign_insurance_B['2020.1']))
y_B.append((int)(foreign_insurance_B['2021.1']))

y_P = []

y_P.append((int)(foreign_insurance_P['2004.1']))
y_P.append((int)(foreign_insurance_P['2005.1']))
y_P.append((int)(foreign_insurance_P['2006.1']))
y_P.append((int)(foreign_insurance_P['2007.1']))
y_P.append((int)(foreign_insurance_P['2008.1']))
y_P.append((int)(foreign_insurance_P['2009.1']))
y_P.append((int)(foreign_insurance_P['2010.1']))
y_P.append((int)(foreign_insurance_P['2011.1']))
y_P.append((int)(foreign_insurance_P['2012.1']))
y_P.append((int)(foreign_insurance_P['2013.1']))
y_P.append((int)(foreign_insurance_P['2014.1']))
y_P.append((int)(foreign_insurance_P['2015.1']))
y_P.append((int)(foreign_insurance_P['2016.1']))
y_P.append((int)(foreign_insurance_P['2017.1']))
y_P.append((int)(foreign_insurance_P['2018.1']))
y_P.append((int)(foreign_insurance_P['2019.1']))
y_P.append((int)(foreign_insurance_P['2020.1']))
y_P.append((int)(foreign_insurance_P['2021.1']))

y_M =[]

y_M.append((int)(foreign_insurance_M['2004.1']))
y_M.append((int)(foreign_insurance_M['2005.1']))
y_M.append((int)(foreign_insurance_M['2006.1']))
y_M.append((int)(foreign_insurance_M['2007.1']))
y_M.append((int)(foreign_insurance_M['2008.1']))
y_M.append((int)(foreign_insurance_M['2009.1']))
y_M.append((int)(foreign_insurance_M['2010.1']))
y_M.append((int)(foreign_insurance_M['2011.1']))
y_M.append((int)(foreign_insurance_M['2012.1']))
y_M.append((int)(foreign_insurance_M['2013.1']))
y_M.append((int)(foreign_insurance_M['2014.1']))
y_M.append((int)(foreign_insurance_M['2015.1']))
y_M.append((int)(foreign_insurance_M['2016.1']))
y_M.append((int)(foreign_insurance_M['2017.1']))
y_M.append((int)(foreign_insurance_M['2018.1']))
y_M.append((int)(foreign_insurance_M['2019.1']))
y_M.append((int)(foreign_insurance_M['2020.1']))
y_M.append((int)(foreign_insurance_M['2021.1']))

y_PA =[]

y_PA.append((int)(foreign_insurance_PA['2004.1']))
y_PA.append((int)(foreign_insurance_PA['2005.1']))
y_PA.append((int)(foreign_insurance_PA['2006.1']))
y_PA.append((int)(foreign_insurance_PA['2007.1']))
y_PA.append((int)(foreign_insurance_PA['2008.1']))
y_PA.append((int)(foreign_insurance_PA['2009.1']))
y_PA.append((int)(foreign_insurance_PA['2010.1']))
y_PA.append((int)(foreign_insurance_PA['2011.1']))
y_PA.append((int)(foreign_insurance_PA['2012.1']))
y_PA.append((int)(foreign_insurance_PA['2013.1']))
y_PA.append((int)(foreign_insurance_PA['2014.1']))
y_PA.append((int)(foreign_insurance_PA['2015.1']))
y_PA.append((int)(foreign_insurance_PA['2016.1']))
y_PA.append((int)(foreign_insurance_PA['2017.1']))
y_PA.append((int)(foreign_insurance_PA['2018.1']))
y_PA.append((int)(foreign_insurance_PA['2019.1']))
y_PA.append((int)(foreign_insurance_PA['2020.1']))
y_PA.append((int)(foreign_insurance_PA['2021.1']))

y_VIE =[]

y_VIE.append((int)(foreign_insurance_Vie['2004.1']))
y_VIE.append((int)(foreign_insurance_Vie['2005.1']))
y_VIE.append((int)(foreign_insurance_Vie['2006.1']))
y_VIE.append((int)(foreign_insurance_Vie['2007.1']))
y_VIE.append((int)(foreign_insurance_Vie['2008.1']))
y_VIE.append((int)(foreign_insurance_Vie['2009.1']))
y_VIE.append((int)(foreign_insurance_Vie['2010.1']))
y_VIE.append((int)(foreign_insurance_Vie['2011.1']))
y_VIE.append((int)(foreign_insurance_Vie['2012.1']))
y_VIE.append((int)(foreign_insurance_Vie['2013.1']))
y_VIE.append((int)(foreign_insurance_Vie['2014.1']))
y_VIE.append((int)(foreign_insurance_Vie['2015.1']))
y_VIE.append((int)(foreign_insurance_Vie['2016.1']))
y_VIE.append((int)(foreign_insurance_Vie['2017.1']))
y_VIE.append((int)(foreign_insurance_Vie['2018.1']))
y_VIE.append((int)(foreign_insurance_Vie['2019.1']))
y_VIE.append((int)(foreign_insurance_Vie['2020.1']))
y_VIE.append((int)(foreign_insurance_Vie['2021.1']))

y_Uz =[]

y_Uz.append((int)(foreign_insurance_Uz['2004.1']))
y_Uz.append((int)(foreign_insurance_Uz['2005.1']))
y_Uz.append((int)(foreign_insurance_Uz['2006.1']))
y_Uz.append((int)(foreign_insurance_Uz['2007.1']))
y_Uz.append((int)(foreign_insurance_Uz['2008.1']))
y_Uz.append((int)(foreign_insurance_Uz['2009.1']))
y_Uz.append((int)(foreign_insurance_Uz['2010.1']))
y_Uz.append((int)(foreign_insurance_Uz['2011.1']))
y_Uz.append((int)(foreign_insurance_Uz['2012.1']))
y_Uz.append((int)(foreign_insurance_Uz['2013.1']))
y_Uz.append((int)(foreign_insurance_Uz['2014.1']))
y_Uz.append((int)(foreign_insurance_Uz['2015.1']))
y_Uz.append((int)(foreign_insurance_Uz['2016.1']))
y_Uz.append((int)(foreign_insurance_Uz['2017.1']))
y_Uz.append((int)(foreign_insurance_Uz['2018.1']))
y_Uz.append((int)(foreign_insurance_Uz['2019.1']))
y_Uz.append((int)(foreign_insurance_Uz['2020.1']))
y_Uz.append((int)(foreign_insurance_Uz['2021.1']))

x =[]

x.append((int)(foreign_worker['2004']))
x.append((int)(foreign_worker['2005']))
x.append((int)(foreign_worker['2006']))
x.append((int)(foreign_worker['2007']))
x.append((int)(foreign_worker['2008']))
x.append((int)(foreign_worker['2009']))
x.append((int)(foreign_worker['2010']))
x.append((int)(foreign_worker['2011']))
x.append((int)(foreign_worker['2012']))
x.append((int)(foreign_worker['2013']))
x.append((int)(foreign_worker['2014']))
x.append((int)(foreign_worker['2015']))
x.append((int)(foreign_worker['2016']))
x.append((int)(foreign_worker['2017']))
x.append((int)(foreign_worker['2018']))
x.append((int)(foreign_worker['2019']))
x.append((int)(foreign_worker['2020']))
x.append((int)(foreign_worker['2021']))







foreign_insurance_B
# Out:
# C:\Users\voice\AppData\Local\Temp\ipykernel_23836\1854686840.py:27: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   y.append((int)(foreign_insurance['2004']))
# C:\Users\voice\AppData\Local\Temp\ipykernel_23836\1854686840.py:28: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   y.append((int)(foreign_insurance['2005']))
# C:\Users\voice\AppData\Local\Temp\ipykernel_23836\1854686840.py:29: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   y.append((int)(foreign_insurance['2006']))
# C:\Users\voice\AppData\Local\Temp\ipykernel_23836\1854686840.py:30: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
# ...

# %%
x_l = sm.add_constant(x)

model_1 = sm.OLS(y,x_l).fit()
pred1 = model_1.predict(x_l)
pred0 = np.dot(x_l,model_1.params)







print(model_1.summary())

plt.figure(1)
plt.title('E9 인원 대비 보험금 수령 인원')
plt.plot(x,y,'o')
plt.plot(x,pred0)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.062
# Method:                 Least Squares   F-statistic:                  0.002563
# Date:                Mon, 10 Jul 2023   Prob (F-statistic):              0.960
# Time:                        18:22:25   Log-Likelihood:                -173.13
# No. Observations:                  18   AIC:                             350.3
# Df Residuals:                      16   BIC:                             352.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.005e+04   2187.090      4.597      0.000    5416.553    1.47e+04
# ...

# %%
model_2 = sm.OLS(y1,x_l).fit()
pred2 = model_2.predict(x_l)

plt.title('E9 인원 대비 보험금 수령 액')
plt.plot(x,y1,'o')
plt.plot(x,pred2)

print(model_2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.014
# Model:                            OLS   Adj. R-squared:                 -0.047
# Method:                 Least Squares   F-statistic:                    0.2346
# Date:                Mon, 10 Jul 2023   Prob (F-statistic):              0.635
# Time:                        18:22:25   Log-Likelihood:                -471.77
# No. Observations:                  18   AIC:                             947.5
# Df Residuals:                      16   BIC:                             949.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        1.54e+11   3.51e+10      4.386      0.000    7.95e+10    2.28e+11
# ...

# %%
model_c = sm.OLS(y_c,x_l).fit()
pred3 = model_c.predict(x_l)

plt.title('E9 인원 대비 중국인 보험 수령액')
plt.plot(x,y_c,'o')
plt.plot(x,pred3)

print(model_c.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.019
# Model:                            OLS   Adj. R-squared:                 -0.042
# Method:                 Least Squares   F-statistic:                    0.3103
# Date:                Mon, 10 Jul 2023   Prob (F-statistic):              0.585
# Time:                        18:22:25   Log-Likelihood:                -466.61
# No. Observations:                  18   AIC:                             937.2
# Df Residuals:                      16   BIC:                             939.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.054e+11   2.63e+10      3.999      0.001    4.95e+10    1.61e+11
# ...

# %%
model_I = sm.OLS(y_I,x_l).fit()
pred4 = model_I.predict(x_l)

plt.title('E9 인원 대비 인도네시아 보험 수령액')
plt.plot(x,y_I,'o')
plt.plot(x,pred4)

print(model_I.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.060
# Method:                 Least Squares   F-statistic:                   0.04099
# Date:                Mon, 10 Jul 2023   Prob (F-statistic):              0.842
# Time:                        18:22:26   Log-Likelihood:                -393.58
# No. Observations:                  18   AIC:                             791.2
# Df Residuals:                      16   BIC:                             792.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.429e+09   4.56e+08      7.523      0.000    2.46e+09     4.4e+09
# ...

# %%
model_B = sm.OLS(y_B,x_l).fit()
pred_5 = model_B.predict(x_l)

plt.title('E9 인원 대비 방글라데시 보험 수령액')
plt.plot(x,y_B,'o')
plt.plot(x,pred_5)

print(model_B.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.422
# Model:                            OLS   Adj. R-squared:                  0.386
# Method:                 Least Squares   F-statistic:                     11.70
# Date:                Mon, 10 Jul 2023   Prob (F-statistic):            0.00350
# Time:                        18:22:26   Log-Likelihood:                -380.81
# No. Observations:                  18   AIC:                             765.6
# Df Residuals:                      16   BIC:                             767.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.741e+09   2.24e+08     12.224      0.000    2.27e+09    3.22e+09
# ...

# %%
model_P = sm.OLS(y_P,x_l).fit()
pred_6 = model_P.predict(x_l)

plt.title('E9 인원 대비 필리핀 보험 수령액')
plt.plot(x,y_P,'o')
plt.plot(x,pred_6)

print(model_P.summary())
# Out:
# C:\Users\voice\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                 -0.049
# Method:                 Least Squares   F-statistic:                    0.2012
# Date:                Mon, 10 Jul 2023   Prob (F-statistic):              0.660
# Time:                        18:22:26   Log-Likelihood:                -390.44
# No. Observations:                  18   AIC:                             784.9
# Df Residuals:                      16   BIC:                             786.7
# Df Model:                           1
# ...

# %%
model_M = sm.OLS(y_M,x_l).fit()
pred_M = model_M.predict(x_l)

plt.title('E9 인원 대비 몽골 보험 수령액')
plt.plot(x,y_M,'o')
plt.plot(x,pred_M)

print(model_M.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.054
# Model:                            OLS   Adj. R-squared:                 -0.005
# Method:                 Least Squares   F-statistic:                    0.9095
# Date:                Mon, 10 Jul 2023   Prob (F-statistic):              0.354
# Time:                        18:22:26   Log-Likelihood:                -391.08
# No. Observations:                  18   AIC:                             786.2
# Df Residuals:                      16   BIC:                             787.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.741e+09   3.97e+08      6.909      0.000     1.9e+09    3.58e+09
# ...

# %%
model_PA = sm.OLS(y_PA,x_l).fit()
pred_PA = model_PA.predict(x_l)

plt.title('E9 인원 대비 파키스탄 보험 수령액')
plt.plot(x,y_PA,'o')
plt.plot(x,pred_PA)

print(model_PA.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.246
# Model:                            OLS   Adj. R-squared:                  0.199
# Method:                 Least Squares   F-statistic:                     5.225
# Date:                Mon, 10 Jul 2023   Prob (F-statistic):             0.0362
# Time:                        18:22:27   Log-Likelihood:                -381.48
# No. Observations:                  18   AIC:                             767.0
# Df Residuals:                      16   BIC:                             768.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.438e+09   2.33e+08     10.473      0.000    1.94e+09    2.93e+09
# ...

# %%
model_Vie = sm.OLS(y_VIE,x_l).fit()
pred_Vie = model_Vie.predict(x_l)

plt.title('E9 인원 대비 베트남 보험 수령액')
plt.plot(x,y_VIE,'o')
plt.plot(x,pred_Vie)

print(model_Vie.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                 -0.059
# Method:                 Least Squares   F-statistic:                   0.05998
# Date:                Mon, 10 Jul 2023   Prob (F-statistic):              0.810
# Time:                        18:22:27   Log-Likelihood:                -415.56
# No. Observations:                  18   AIC:                             835.1
# Df Residuals:                      16   BIC:                             836.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       7.036e+09   1.55e+09      4.552      0.000    3.76e+09    1.03e+10
# ...

# %%
model_Uz = sm.OLS(y_Uz,x_l).fit()
pred_Uz = model_Uz.predict(x_l)

plt.title('E9 인원 대비 우즈베키스탄 보험 수령액')
plt.plot(x,y_Uz,'o')
plt.plot(x,pred_Uz)

print(model_Uz.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.035
# Model:                            OLS   Adj. R-squared:                 -0.025
# Method:                 Least Squares   F-statistic:                    0.5836
# Date:                Mon, 10 Jul 2023   Prob (F-statistic):              0.456
# Time:                        18:22:27   Log-Likelihood:                -416.36
# No. Observations:                  18   AIC:                             836.7
# Df Residuals:                      16   BIC:                             838.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.987e+09   1.62e+09      3.705      0.002    2.56e+09    9.41e+09
# ...
